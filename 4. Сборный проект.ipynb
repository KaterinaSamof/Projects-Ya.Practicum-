# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Екатерина! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Обращаю внимание, что комментарии ревьюера после проверки удалять нельзя они помогают отследить логику исправления или изменения проекта. Это дополнительный навык при обучении. Свой исправляемый код лучше тоже не удалять, а ремить #, это позволит акцентировать изменения в ходе подготовки окончательного варианта проекта.<br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что получилось!</b></font>

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# <b>Цель исследования</b>

# %% [markdown]
# 1. Изучить рынок российского кинопроката и выявить текущие тренды.
# 2. Определить, насколько фильмы, получившие господдержжку, интересны зрителю.

# %% [markdown]
# <b>Ход исследования</b>

# %% [markdown]
# Наше исследование представляет собой анализ рынка российского кинопроката для Министерства культуры РФ.
#
# Проведу предобработку - проверю на ошибки, пропуски, дубликаты.
# Создам новые столбцы, проведу исследовательскй анализ.
#
# Таким образом, мое исследование пройдет в пять этапов:
#
# - Обзор данных (открытие и объединение таблиц).
# - Предобработка данных (преобразование типов данных, обработка пропусков и дубликатов, добавление столбцов).
# - Исследовательский анализ данных (изучение динамики сборов по годам).
# - Анализ фильмов, который получили господдержку.
# - Общий вывод.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделано описание проекта. 👍</font>

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
data = pd.read_csv('/datasets/mkrf_movies.csv')

# %%
data.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %%
shows = pd.read_csv('/datasets/mkrf_shows.csv')

# %%
shows.head()
# Out:
#     puNumber     box_office
# 0  111000113       2,450.00
# 1  111000115      61,040.00
# 2  111000116 153,030,013.40
# 3  111000117  12,260,956.00
# 4  111000118 163,684,057.79

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Экспоненциальный формат представления чисел следовало бы преобразовать и избавиться от лишних знаков после запятых. Это можно сделать если прописать в начале настройку `pandas`, где импортируются библиотеки.<br>
# `pd.set_option('display.float_format', '{:,.2f}'.format)`
# </font>

# %% [markdown]
# <font color='Blue'><b> Спасибо большое! Буду использовать.</b></font>

# %%
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исследовали общую информацию о датасетах.</font>

# %% [markdown]
# Видим, что в датасете movies столбец с номерами прокатных удостоверений имеет тип object, а в shows - int. Приведем данные столбца puNumber к числовому типу.

# %%
data['puNumber'] = pd.to_numeric(data['puNumber'], errors='coerce')

# %% [markdown]
# Соединим датафреймы в один так, чтобы в новый вошли все объекты из movies.

# %%
data = data.merge(shows, on='puNumber', how='left')

# %%
data.describe()
# Out:
#             puNumber  refundable_support  nonrefundable_support  \
# count       7,485.00              332.00                 332.00
# mean  135,196,587.56       11,864,457.83          48,980,988.89
# std    38,352,919.34       24,916,555.26          59,980,117.92
# min     1,811,096.00                0.00                   0.00
# 25%   112,025,118.00                0.00          25,000,000.00
# 50%   121,015,510.00                0.00          30,000,000.00
# 75%   124,003,314.00       15,000,000.00          40,375,000.00
# max   231,001,111.00      180,000,000.00         400,000,000.00
#
#                 budget       box_office
# count           332.00         3,158.00
# mean    127,229,716.68    76,478,696.16
# std     188,588,333.12   240,353,122.82
# min               0.00             0.00
# 25%      42,000,000.00        86,239.00
# 50%      68,649,916.00     2,327,987.55
# 75%     141,985,319.50    23,979,671.02
# max   2,305,074,303.00 3,073,568,690.79

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7485 non-null   float64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# <font color='Blue'><b>В объединенном датасете сохранилось количество строк из mkrf_movies (7486), значит, ничего не потерялось.</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %% [markdown]
# Таким образом, мы открыли и объединили два датасета в один. Теперь у нас есть информация о прокате в российских кинотеатрах, дополненная суммами сборов по номерам прокатных удостоверений.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font> <br><font color='Red'>🛠 В задании прямо указано: "чтобы все объекты из датасета mkrf_movies обязательно вошли в получившийся датафрейм", соответственно необходимо сделать проверку и отразить это в промежуточных выводах.</font>

# %% [markdown]
# <font color='Blue'><b>Имеется в виду вызов data.info() для проверки количества строк? Или что-то другое?... я думала, что how='left' достаточно для выполнения условия "все объекты из первого датасета" :(</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Параметр how='left' при не правильной последовательности датасетов даст сокращенный объединенный датсет. Хорошая практика всегда проверять таблицу после ее обработки.</font>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7485 non-null   float64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %%
data.head(10)
# Out:
#                   title       puNumber           show_start_date  \
# 0      Открытый простор 221,048,915.00  2015-11-27T12:00:00.000Z
# 1  Особо важное задание 111,013,716.00  2016-09-13T12:00:00.000Z
# 2          Особо опасен 221,038,416.00  2016-10-10T12:00:00.000Z
# 3          Особо опасен 221,026,916.00  2016-06-10T12:00:00.000Z
# 4          Особо опасен 221,030,815.00  2015-07-29T12:00:00.000Z
# 5     Остановился поезд 111,013,816.00  2016-09-13T12:00:00.000Z
# 6       Любовь и голуби 111,007,013.00  2013-10-18T12:00:00.000Z
# 7     Любовь и сигареты 221,074,614.00  2014-12-29T12:00:00.000Z
# 8    Отпетые мошенники. 121,011,416.00  2016-05-05T12:00:00.000Z
# 9   Отпуск за свой счет 111,019,114.00  2014-12-01T12:00:00.000Z
#
#              type                                        film_studio  \
# 0  Художественный  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...
# 1  Художественный                              Киностудия "Мосфильм"
# ...

# %%
data['show_start_date'] = pd.to_datetime(data['show_start_date'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, преобразовали колонку `show_start_date` в дату.</font>

# %%
data['refundable_support'] = pd.to_numeric(data['refundable_support'], errors='coerce')

# %%
data['nonrefundable_support'] = pd.to_numeric(data['nonrefundable_support'], errors='coerce')

# %%
data['budget'] = pd.to_numeric(data['budget'], errors='coerce')

# %%
data['ratings'] = pd.to_numeric(data['ratings'], errors='coerce')

# %%
data['box_office'] = pd.to_numeric(data['box_office'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7485 non-null   float64
#  2   show_start_date        7486 non-null   datetime64[ns, UTC]
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6490 non-null   float64
# ...

# %% [markdown]
# Мы удобства работы с данными мы преобразовали тип в ряде столбцов:
#
# - изменили тип данных в столбце дата премьеры фильма (show_start_date) на дату;
# - в столбцах refundable_support, nonrefundable_support, budget, ratings, box_office  тип приведен к числовому.

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше перед обработкой пропусков делать контроль размера датасета до и после обработки. Примерно вот так:</font>

# %%
# Комментарий ревьюера
temp = data.copy() # создаем копию датасета до преобразования
len(temp)
# Out:
# 7486

# %% [markdown]
# <font color='Blue'><b>Спасибо, буду применять!</b></font>

# %% [markdown]
# Проверим количество пропуков в %.

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_2021b_row0_col0,#T_2021b_row1_col0,#T_2021b_row2_col0,#T_2021b_row3_col0,#T_2021b_row4_col0,#T_2021b_row5_col0,#T_2021b_row6_col0,#T_2021b_row8_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2021b_row7_col0{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_2021b_row9_col0,#T_2021b_row10_col0,#T_2021b_row11_col0,#T_2021b_row12_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2021b_row13_col0,#T_2021b_row14_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_2021b_row15_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }</style><table id="T_2021b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
data.isna().sum()
# Out:
# title                       0
# puNumber                    1
# show_start_date             0
# type                        0
# film_studio                18
# production_country          2
# director                    9
# producer                  568
# age_restriction             0
# refundable_support       7154
# nonrefundable_support    7154
# budget                   7154
# financing_source         7154
# ratings                   996
# genres                    976
# box_office               4328
# dtype: int64

# %%
data.describe()
# Out:
#             puNumber  refundable_support  nonrefundable_support  \
# count       7,485.00              332.00                 332.00
# mean  135,196,587.56       11,864,457.83          48,980,988.89
# std    38,352,919.34       24,916,555.26          59,980,117.92
# min     1,811,096.00                0.00                   0.00
# 25%   112,025,118.00                0.00          25,000,000.00
# 50%   121,015,510.00                0.00          30,000,000.00
# 75%   124,003,314.00       15,000,000.00          40,375,000.00
# max   231,001,111.00      180,000,000.00         400,000,000.00
#
#                 budget  ratings       box_office
# count           332.00 6,490.00         3,158.00
# mean    127,229,716.68     6.48    76,478,696.16
# std     188,588,333.12     1.10   240,353,122.82
# min               0.00     1.00             0.00
# 25%      42,000,000.00     5.90        86,239.00
# 50%      68,649,916.00     6.60     2,327,987.55
# ...

# %%
# Больше всего информации отсутствует о государственной поддержки, бюджете и источнике гос финансирования. Попытка замены значений в таких количествах может привести к искажению информации, поэтому лучше оставить так, как есть.

# %%
data[data['refundable_support'].isna() & data['nonrefundable_support'].isna() & data['financing_source'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7154 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7154 non-null   object
#  1   puNumber               7153 non-null   float64
#  2   show_start_date        7154 non-null   datetime64[ns, UTC]
#  3   type                   7154 non-null   object
#  4   film_studio            7136 non-null   object
#  5   production_country     7152 non-null   object
#  6   director               7145 non-null   object
#  7   producer               6588 non-null   object
#  8   age_restriction        7154 non-null   object
#  9   refundable_support     0 non-null      float64
#  10  nonrefundable_support  0 non-null      float64
#  11  budget                 0 non-null      float64
#  12  financing_source       0 non-null      object
#  13  ratings                6176 non-null   float64
# ...

# %%
# Предполагаем, что отсутсвие значений в столбцах financing_source, refundable_support, nonrefundable_support означает отсутствие гос поддержки.

# %%
data['financing_source'] = data['financing_source'].fillna(value='Без гос финансирования')

# %%
data['refundable_support'] = data['refundable_support'].fillna(-1)

# %%
data['nonrefundable_support'] = data['nonrefundable_support'].fillna(-1)

# %% [markdown]
# <font color='Blue'><b>Поменяла значение заглушек на -1, так как нулевые значения по сборам, бюджету и средствам финансирования уже были в датасете (и, соответственно, их не получается безопасно отфильтровать при необходимости</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Допустимая замена пропусков заглушками. Надо иметь в виду, что при анализе заглушки надо будет отфильтровывать.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера: Глоссарий</b></font><br>
# <font color='DarkGreen'>👌 В контексте анализа и предобработки датасета часто используютется термин: <b>Заглушка (значение-индикатор)</b>. <br>Из словаря: "Заглушка — приспособление для закрывания отверстия наглухо." <br>В нашем контексте закрытие пропуска в датасете каким-то значением, совпадающим по типу с данными колонки таблицы. Как правило, для числовых данных заглушка должна быть вне диапазона значений колонки. При анализе по данной колонке заглушка или фильтруется, или включается в анализ, если сам пропуск не является ошибкой сбора данных и несет какой-то признак. <br>Частая ошибка, когда заглушке присваивается числовое значение, например `0`, а в данных колонки присутствуют символьные значения `'0'`, то при преобразовании к числовому типу произойдет слияние значимых данных таблицы и заглушки.<br>Синонимами термина "заглушка", которые используются на практике, являются "значение-индикатор" и "маркер".</font>

# %% [markdown]
# <font color='Blue'><b>То есть в рамках нашей задачи можно было оставить пропуски в сборах, гос средствах и бюджете NaN?</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Правильно!</font>

# %%
# В столбце с источниками финансирования пропуски заменены на "Без гос финансирования" и средства гос поддержки в пропусках заменены на 0.

# %% [markdown]
# В столбце с источниками финансирования пропуски заменены на "Без гос финансирования" и средства гос поддержки в пропусках заменены на -1.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Следовало в заключение вывести информацию об оставшихся пропусках, как итог их обработки.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не проведен детальный анализ пропусков в датасете. Необходимо рассмотреть каждую колонку с пропусками и принять обоснованное решение по их обработке.</font>

# %% [markdown]
# Пропуски в puNumber

# %%
data.query('puNumber.isna()')
# Out:
#                                   title  puNumber           show_start_date  \
# 1797  Курбан-роман. (История с жертвой)       NaN 2014-05-15 12:00:00+00:00
#
#                 type       film_studio production_country director  \
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 1797  М.Галицкая  «12+» - для детей старше 12 лет               -1.00
#
#       nonrefundable_support  budget        financing_source  ratings genres  \
# 1797                  -1.00     NaN  Без гос финансирования      NaN    NaN
#
#       box_office
# 1797         NaN

# %% [markdown]
# В рамках нашей задачи сам номер прокатного удостоверения роли не играет. Можно заменить на ноль, просто ради устранения пропуска в данных.

# %%
data['puNumber'] = data['puNumber'].fillna(0)

# %%
data['puNumber'] = data['puNumber'].astype('int')

# %% [markdown]
# Пропуски в film_studio

# %%
data.query('film_studio.isna()')
# Out:
#                                          title   puNumber  \
# 1293                           Stars in Shorts  121011114
# 4441                  Мульт личности. Выпуск 5  214000410
# 6105                              Значит любит  111013818
# 6181                     Несейка. Младшая дочь  112007018
# 6379                              Ян Антонышев  112011818
# 6380                              Ян Антонышев  112011918
# 6399                     Доживем до каникул?..  111021918
# 6485                                До и После  112014418
# 6494            Калмыцкий геше Нгаванг Вангьял  113002018
# 6497                        Мой папа Чингисхан  112014918
# 6498                       В плену города грёз  112014818
# 6499                            Последнее фото  112014518
# 6507                              Мой селфхарм  113001918
# 6511            Обстоятельства места и времени  112015018
# 6638  Эрик Булатов. Моя Третьяковка, серии 1-2  113000319
# ...

# %% [markdown]
# Не вижу никаких закономерностей у фильмов с пропусками в студии-производителе. Заменю пропуски на "Нет данных"

# %%
data['film_studio'] = data['film_studio'].fillna('Нет данных')

# %% [markdown]
# Пропуски в production_country

# %%
data.query('production_country.isna()')
# Out:
#                                                   title   puNumber  \
# 3186  Детский юмористический киножурнал "Ералаш. Ну ...  111001216
# 4441                           Мульт личности. Выпуск 5  214000410
#
#                show_start_date            type  \
# 3186 2016-02-09 12:00:00+00:00  Художественный
# 4441 2010-01-25 12:00:00+00:00  Художественный
#
#                           film_studio production_country  \
# 3186  ООО "Продюсерский центр ЕРАЛАШ"                NaN
# 4441                       Нет данных                NaN
#
#                                                director  \
# 3186  Р.Светлов, И.Магитон, А.Арутюнян, Л.Мирский, А...
# 4441                                                NaN
#
#                              producer                         age_restriction  \
# 3186  ООО "Продюсерский центр ЕРАЛАШ"  «0+» - для любой зрительской аудитории
# 4441                              NaN  «0+» - для любой зрительской аудитории
#
# ...

# %%
# В этих фильмах я отчетливо ощущаю русскую душу. Возьму на себя смелость заменить пропуски на "РРРРА СИ Я". То есть "Россия".

# %%
data['production_country'] = data['production_country'].fillna('Россия')

# %% [markdown]
# Пропуски в director

# %%
data.query('director.isna()')
# Out:
#                                                   title   puNumber  \
# 764   Три звезды. Концерт в Waldbuhne Theater, Берли...  126003512
# 1735                           Помпеи. Британский музей  126003413
# 3840                     Зур концерт (Большой концерт).  217027010
# 4052  Ганс Сэйфуллин "Авылым чишмэлэре. Ганс Сэйфулл...  217017310
# 4298                        Изге Вэли (Святой Валентин)  217020610
# 4415                          Bon Jovi. The Circle Tour  126001710
# 4441                           Мульт личности. Выпуск 5  214000410
# 4923  Георг Фридрих Гендель. Мессия. Оратория. Корол...  126001111
# 4942             Питер Гэбриэл и New Blood Orchestra 3D  126002711
#
#                show_start_date            type                   film_studio  \
# 764  2012-12-04 12:00:00+00:00          Прочие            Райзинг Алтернатив
# 1735 2013-09-11 12:00:00+00:00          Прочие  МортуСкрин, Британский музей
# ...

# %%
# Здесь я уже снова ничего не чувствую... заменю на "Нет данных"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data['director'] = data['director'].fillna('Нет данных')

# %% [markdown]
# Пропуски в producer

# %%
data.query('producer.isna()')
# Out:
#                               title   puNumber           show_start_date  \
# 1              Особо важное задание  111013716 2016-09-13 12:00:00+00:00
# 5                 Остановился поезд  111013816 2016-09-13 12:00:00+00:00
# 6                   Любовь и голуби  111007013 2013-10-18 12:00:00+00:00
# 9               Отпуск за свой счет  111019114 2014-12-01 12:00:00+00:00
# 11                     Ответный ход  111019014 2014-12-01 12:00:00+00:00
# ...                             ...        ...                       ...
# 7405  Отряд специального назначения  111020419 2019-12-01 12:00:00+00:00
# 7406           Назначаешься внучкой  111020519 2019-12-01 12:00:00+00:00
# 7407                Перед рассветом  111020619 2019-12-01 12:00:00+00:00
# 7408                     Ты помнишь  111020719 2019-12-01 12:00:00+00:00
# 7409               Здесь твой фронт  111020819 2019-12-01 12:00:00+00:00
#
#                  type                             film_studio  \
# ...

# %%
data['producer'] = data['producer'].fillna('Нет данных')

# %% [markdown]
# Пропуски в budget

# %%
data.query('budget.isna()')
# Out:
#                                              title   puNumber  \
# 0                                 Открытый простор  221048915
# 1                             Особо важное задание  111013716
# 2                                     Особо опасен  221038416
# 3                                     Особо опасен  221026916
# 4                                     Особо опасен  221030815
# ...                                            ...        ...
# 7481     Сад художника: Американский импрессионизм  126008019
# 7482                               Звериная ярость  121037819
# 7483     Щенячий патруль: Скорей спешим на помощь!  124010819
# 7484      Машины песенки. Серия "Испанские мотивы"  124010619
# 7485  Машины песенки. Серия "Когда цветут кактусы"  124010719
#
#                show_start_date             type  \
# 0    2015-11-27 12:00:00+00:00   Художественный
# 1    2016-09-13 12:00:00+00:00   Художественный
# 2    2016-10-10 12:00:00+00:00   Художественный
# ...

# %%
data['budget'] = data['budget'].fillna(-1)

# %% [markdown]
# Пропуски в ratings

# %%
data.query('ratings.isna()')
# Out:
#                                                  title   puNumber  \
# 43            Мемуары гейши (по роману Артура Голдена)  121000606
# 150                                           Жди меня  111013615
# 154   Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159                                  Жемчужная девушка  224011014
# 227                                         Полустанок  111026714
# ...                                                ...        ...
# 7479                                            Эколав  111023219
# 7480                   Акрам Хан: Родом из Карри Хауса  126007919
# 7481         Сад художника: Американский импрессионизм  126008019
# 7483         Щенячий патруль: Скорей спешим на помощь!  124010819
# 7484          Машины песенки. Серия "Испанские мотивы"  124010619
#
#                show_start_date             type  \
# 43   2012-12-14 12:00:00+00:00   Художественный
# 150  2015-08-25 12:00:00+00:00   Художественный
# ...

# %% [markdown]
# Рейтингам тоже можно поставить заглушку... А чем заглушка лучше, чем оставить без изменений?

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 В чем разница, оставлять NaN или ставить заглушку при обработке пропусков:<br>
# - NaN не мешают при построении графиков и расчете корреляции (если это требуется), при расчете средних и медиан, но искажает расчеты в статистике (на пример в тесте Стьюдента получим NaN). А так как пропуск не везде мешает, то мы можем забыть его отфильтровать и получить не верный результат. В отдельных случаях наличие пропуска в датасете не связано с низким качеством сбора данных датасета, а может являтся значимым признаком, но если пропуск не заменим на заглушку, то этого даже не заметим.
# - Заглушка везде мешает, по этому при анализе целевого параметра, который в датасете содержал NaN, всегда отфильтровываем ее. Заглушку лучше ставить далеко вне диапазона целевых параметров. Если вдруг забудем ее отфильтровать, то сразу заметим при преобразованиях. Кроме того, заглушка показывает, что оценили количество пропусков в датасете и приняли по ним обоснованное решение. Необходимо помнить, что не отфильтрованная заглушка в числовых данных будет искажать расчеты средних, медиан и диаграммы размаха. <br>Но можем сделать анализ и с учетом заглушки и обнаружить неявный признак, который нес пропуск.</font>

# %% [markdown]
# <font color='Blue'><b>Тогда я не понимаю, зачем мы вообще сюда добавили заглушки, если они не искажали результаты в рамках нашей задачи(...</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkMagenta'>👉 Я не добавлял. <br>Половину колонок здесь не анализируем. Признак госфинонсирования - сумма господдержки больше нуля или не нулевой бюджет, признак выхода фильма в прокат - не нулевая сумма сборов. Пропуск в рейтинге фильма - фильм не набрал  достаточного количества индивидуальных оценок для формирования итоговой оценки. Для расчета сумм, средних и медиан пропуск не мешает, диаграммы строить то же. Делать расчет статистики, например т-тест в проекте не надо, в противном случае надо было фильтровать пропуски, а если пославены зглушки, то их все равно надо было бы фильтровать.<br>Так зачем вставили заглушки?</font>

# %% [markdown]
# <font color='Blue'><b>Я вообще не знала о существовании такого термина, пока ты не оставил комментарий о них 🙈
#     Я, получается, изначально неправильно поняла замечания об обработке пропусков после первой отправки проекта... подумала, что надо было обязательно всё на что-то заменить... ((</b></font>

# %%
data['ratings'] = data['ratings'].fillna(0)

# %% [markdown]
# Пропуски в genres

# %%
data.query('genres.isna()')
# Out:
#                                                  title   puNumber  \
# 43            Мемуары гейши (по роману Артура Голдена)  121000606
# 150                                           Жди меня  111013615
# 154   Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159                                  Жемчужная девушка  224011014
# 227                                         Полустанок  111026714
# ...                                                ...        ...
# 7479                                            Эколав  111023219
# 7480                   Акрам Хан: Родом из Карри Хауса  126007919
# 7481         Сад художника: Американский импрессионизм  126008019
# 7483         Щенячий патруль: Скорей спешим на помощь!  124010819
# 7484          Машины песенки. Серия "Испанские мотивы"  124010619
#
#                show_start_date             type  \
# 43   2012-12-14 12:00:00+00:00   Художественный
# 150  2015-08-25 12:00:00+00:00   Художественный
# ...

# %%
data['genres'] = data['genres'].fillna('Нет данных')

# %% [markdown]
# Пропуски в box_office

# %%
data.query('box_office.isna()')
# Out:
#                                              title   puNumber  \
# 0                                 Открытый простор  221048915
# 1                             Особо важное задание  111013716
# 2                                     Особо опасен  221038416
# 3                                     Особо опасен  221026916
# 4                                     Особо опасен  221030815
# ...                                            ...        ...
# 7481     Сад художника: Американский импрессионизм  126008019
# 7482                               Звериная ярость  121037819
# 7483     Щенячий патруль: Скорей спешим на помощь!  124010819
# 7484      Машины песенки. Серия "Испанские мотивы"  124010619
# 7485  Машины песенки. Серия "Когда цветут кактусы"  124010719
#
#                show_start_date             type  \
# 0    2015-11-27 12:00:00+00:00   Художественный
# 1    2016-09-13 12:00:00+00:00   Художественный
# 2    2016-10-10 12:00:00+00:00   Художественный
# ...

# %%
data['box_office'] = data['box_office'].fillna(-1)

# %%
data.isna().sum()
# Out:
# title                    0
# puNumber                 0
# show_start_date          0
# type                     0
# film_studio              0
# production_country       0
# director                 0
# producer                 0
# age_restriction          0
# refundable_support       0
# nonrefundable_support    0
# budget                   0
# financing_source         0
# ratings                  0
# genres                   0
# box_office               0
# dtype: int64

# %%
len(data)
# Out:
# 7486

# %% [markdown]
# В результате, мы заменили все пропуски в нашем датасете. Количество строк сохранилось, 7486.

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что проверены явные дубликаты, иногда они сильно искажают анализ.</font>

# %% [markdown]
# Явных дубликатов нет

# %%
data[data['title'].duplicated()].head()
# Out:
#                                                  title   puNumber  \
# 3                                         Особо опасен  221026916
# 4                                         Особо опасен  221030815
# 41                                        Алекс и Эмма  221004616
# 110  Гарри Поттер и орден Феникса /По роману Дж.К.Р...  121026316
# 113  Гарри Поттер и узник Азкабана /По роману Дж.К....  121026116
#
#               show_start_date            type  \
# 3   2016-06-10 12:00:00+00:00  Художественный
# 4   2015-07-29 12:00:00+00:00  Художественный
# 41  2016-02-09 12:00:00+00:00  Художественный
# 110 2016-09-23 12:00:00+00:00  Художественный
# 113 2016-09-23 12:00:00+00:00  Художественный
#
#                                            film_studio    production_country  \
# 3    Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                   США
# 4    Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                   США
# ...

# %%
data.query('puNumber.duplicated(keep=False)')
# Out:
#                                                   title   puNumber  \
# 4638                   Как жениться и остаться холостым  221154310
# 4639  Иоанна - женщина на папском престоле /По роман...  221154310
# 5067                                    Анализируй это!  221054410
# 5068                                     Анализируй то!  221054410
#
#                show_start_date            type  \
# 4638 2010-12-17 12:00:00+00:00  Художественный
# 4639 2010-12-17 12:00:00+00:00  Художественный
# 5067 2010-05-25 12:00:00+00:00  Художественный
# 5068 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4638  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4639   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
# 5067          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 5068  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#                                 production_country        director  \
# ...

# %% [markdown]
# Для того, чтобы номера прокатных удостоверений были уникальными, присвоимновые номера для повторяющихся.

# %%
data.query('title.str.contains("Как жениться и остаться холостым")')
# Out:
#                                  title   puNumber           show_start_date  \
# 4520  Как жениться и остаться холостым  221142510 2010-12-03 12:00:00+00:00
# 4638  Как жениться и остаться холостым  221154310 2010-12-17 12:00:00+00:00
#
#                 type                                        film_studio  \
# 4520  Художественный  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4638  Художественный  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
#
#      production_country      director                 producer  \
# 4520            Франция  Эрик Лартиго  Амандин Било, Алан Шаба
# 4638            Франция  Эрик Лартиго  Амандин Било, Алан Шаба
#
#                       age_restriction  refundable_support  \
# 4520  «16+» - для детей старше 16 лет               -1.00
# 4638  «16+» - для детей старше 16 лет               -1.00
#
#       nonrefundable_support  budget        financing_source  ratings  \
# 4520                  -1.00   -1.00  Без гос финансирования     7.00
# ...

# %%
data['puNumber'] = data['puNumber'].where(data['title']!= 'Анализируй то!', '111111111')

# %%
data.loc[(data['title'] == 'Как жениться и остаться холостым') & (data['puNumber'] == 221154310), 'puNumber'] = 222222222

# %%
data.query('puNumber.duplicated(keep=False)')
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %% [markdown]
# Дубликаты в столбцах с характеристиками объясняются разнообразием фильмов в выборке и различием в подходе к записи наименований фильмов и фамилий режиссеров. Среди названий фильмов дубликаты также могут быть вызваны различием премьерных дат и прокатных удостоверений.
#
# В колонке прокатных удостоверений устранены дубликаты в номерах, так как они должны быть уникальными.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Стоило проверить на неявные (неполные) дубликаты колонку с номерами прокатных удостоверений, явно они должны быть уникальными.</font>

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['type'].unique()
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', ' Художественный', ' Анимационный',
#        'Музыкально-развлекательный'], dtype=object)

# %% [markdown]
# Устраняем лишние пробелы

# %%
data['type'] = data['type'].str.strip()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, решили проблему в колонке type.</font>

# %%
data['type'].unique()
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', 'Музыкально-развлекательный'], dtype=object)

# %% [markdown]
# Устраним лишние пробелы и в остальных столбцах
# Видим аналогичную проблему в столбце со странами-производителями

# %%
data['title'] = data['title'].str.strip()

# %%
data['film_studio'] = data['film_studio'].str.strip()

# %%
data['director'] = data['director'].str.strip()

# %%
data['producer'] = data['producer'].str.strip()

# %%
data['production_country'] = data['production_country'].str.strip()

# %%
data['age_restriction'] = data['age_restriction'].str.strip()

# %%
data['financing_source'] = data['financing_source'].str.strip()

# %%
data['title'].sort_values().unique()
# Out:
# array(['"SOS" над тайгой', '"V" значит вендетта',
#        '"АРТиШОК" анимационный альманах авторских фильмов', ...,
#        'Ярость / Fury',
#        'альманах документальных фильмов "Вокзалы России: История, Любовь и Великие тайны…" Фильм первый "ВОКЗАЛЫ РОССИИ СВЯЗЬ ВРЕМЕН"',
#        'сНежное шоу'], dtype=object)

# %%
data['film_studio'].sort_values().unique()
# Out:
# array(['"Дино де Лаурентиис" (Италия) при участии Киностудии "Мосфильм"',
#        '"Союздетфильм", "Мосфильм", "Москинокомбинат"',
#        '"Студия "Птица Феникс" Татьяны Новиковой', ...,
#        'ристалл Сити Интертейнмент, Эксклюзив Медиа Групп, Хоуп Таун Интертейнмент, Каппа Андерковар Пикчерз, Скарлет Файр Интертейнмент',
#        'совместное производство Киностудия "Мосфильм", "Космос-филм" (Франция), "Посейдон Продакшинз Лимитед" (Англия), "ИКАИК" (Куба), ДЕФА (ГДР)',
#        'юФилм, Твинпикс'], dtype=object)

# %%
data['director'].sort_values().unique()
# Out:
# array(['Ёлкин Туйчиев', 'Ён Сан-хо', 'А Андрющенко', ...,
#        'хореография Пьера Лакотта по Филиппу Тальони',
#        'хореография Фредерика Аштона', 'хореография Фредерика Эштона'],
#       dtype=object)

# %%
data['producer'].sort_values().unique()
# Out:
# array(['"Фонд Михаила Калатозова"', 'Ёсиаки Нисимура, Джеффри Уэкслер',
#        'А. Калюжный', ...,
#        'Яэль Абекассис, Мат Кирби, Мишель Киркман, Пабло Мелер, Брайан Дж. Фалконер, Стефан Эйхенбергер',
#        'Яэль Бергман, Лаура Уотерс, Питер Хеллайар',
#        'Яэль Фогель, Летиция Гонзалез'], dtype=object)

# %%
data['production_country'].sort_values().unique()
# Out:
# array(['2019', 'CША', 'Австралия',
#        'Австралия - Великобритания - Бельгия - Индия',
#        'Австралия - Германия', 'Австралия - Ирландия',
#        'Австралия - Колумбия', 'Австралия - США', 'Австралия, Канада',
#        'Австралия, США', 'Австралия-Великобритания', 'Австралия-Ирландия',
#        'Австралия-США', 'Австралия-Турция-США', 'Австрия',
#        'Австрия - Германия', 'Австрия - Германия - Франция',
#        'Австрия - Люксембург', 'Австрия, Великобритания, Германия',
#        'Австрия-Германия-Франция', 'Австрия-Франция-Германия',
#        'Азербайджан-Россия', 'Аргентина', 'Аргентина - Бразилия',
#        'Аргентина - Испания', 'Аргентина - Испания - Уругвай',
#        'Аргентина - Мексика - Бразилия - Франция - США',
#        'Аргентина - Уругвай - Россия - Германия - Франция - Нидерланды',
#        'Аргентина - Франция - Испания', 'Аргентина, Испания',
#        'Аргентина-Испания', 'Армения', 'Армения - Германия',
# ...

# %%
data['age_restriction'].sort_values().unique()
# Out:
# array(['«0+» - для любой зрительской аудитории',
#        '«12+» - для детей старше 12 лет',
#        '«16+» - для детей старше 16 лет', '«18+» - запрещено для детей',
#        '«6+» - для детей старше 6 лет'], dtype=object)

# %%
data['financing_source'].sort_values().unique()
# Out:
# array(['Без гос финансирования', 'Министерство культуры',
#        'Министерство культуры, Фонд кино', 'Фонд кино'], dtype=object)

# %% [markdown]
# Видим, что что имена режиссеров, продюссеров, названия фильмов и стран записаны в разных стилях.

# %% [markdown]
# Обнаружены и устранены лишние проблемы в начале и в конце строк типов фильмов, стран-производителей и имен режиссеров.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Общая проблема многих колонок с категориальными данными связана с тем, что они содержат очень много уникальных значений из-за того, что в них идет перечисления отдельных признаков. Так как такие колонки анализировать не возможно, далее выделяем основной жанр и главного режиссёра в отдельные колонки.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не изучены все колонки с категориальными данными. Необходимо найти общую проблему в этих данных, согласно заданию.</font>

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Рекомендуется для анализа количественных данных посмотреть сводную статистику: `df.describe()`.</font>

# %%
data.describe()
# Out:
#        refundable_support  nonrefundable_support           budget  ratings  \
# count            7,486.00               7,486.00         7,486.00 7,486.00
# mean           526,181.25           2,172,279.08     5,642,567.30     5.62
# std          5,781,108.17          16,148,935.57    47,528,177.80     2.43
# min                 -1.00                  -1.00            -1.00     0.00
# 25%                 -1.00                  -1.00            -1.00     5.30
# 50%                 -1.00                  -1.00            -1.00     6.40
# 75%                 -1.00                  -1.00            -1.00     7.10
# max        180,000,000.00         400,000,000.00 2,305,074,303.00     9.20
#
#             box_office
# count         7,486.00
# mean     32,262,853.08
# std     160,600,784.28
# min              -1.00
# 25%              -1.00
# 50%              -1.00
# 75%       1,080,467.99
# max   3,073,568,690.79

# %%
data.query('box_office >= 0 & refundable_support >= 0 & nonrefundable_support >= 0').describe()
# Out:
#        refundable_support  nonrefundable_support           budget  ratings  \
# count              318.00                 318.00           318.00   318.00
# mean        11,946,540.88          48,780,403.50   127,629,459.62     5.68
# std         24,817,662.19          57,792,390.58   186,490,276.88     1.74
# min                  0.00                   0.00             0.00     0.00
# 25%                  0.00          25,000,000.00    42,063,127.25     5.20
# 50%                  0.00          30,000,000.00    70,195,719.50     6.10
# 75%         15,000,000.00          44,125,000.00   148,405,486.00     6.70
# max        180,000,000.00         400,000,000.00 2,305,074,303.00     8.50
#
#             box_office
# count           318.00
# mean    132,432,420.05
# std     334,837,856.99
# min           1,550.00
# 25%       1,236,675.50
# 50%      15,720,067.71
# 75%     106,373,008.27
# max   3,073,568,690.79

# %%
# В колонках объема господдержки , бюджета и сборов очень много неизвестных данных (даже медиана ноль)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Так туда на пропуски поставили нулевые заглушки.</font>

# %%
data.query('box_office >= 0 & refundable_support >= 0 & nonrefundable_support >= 0').boxplot(figsize=(15, 5))
plt.title('Диаграмма размаха количественных данных датасета')
plt.xlabel('Колонка датасета')
plt.ylabel('Размах')
plt.show()

# %% [markdown]
# Самые выдающиеся от значения наблюдаются в колонке сборов кинопроката. Это может быть вызвано аномальными  большими значениями сборов у отдельно взятых фильмов.

# %% [markdown]
# Рассмотрим соотношение бюджета фильма и средств гос поддержки. Логично предположить, что гос поддержка не может превышать бюджет. Проверим, есть ли в нашей выборке фильмы, не подходящие под эту логику.

# %%
data.query('box_office >= 0 & refundable_support >= 0 & nonrefundable_support >= 0  & budget < (refundable_support + nonrefundable_support)')
# Out:
#                        title   puNumber           show_start_date  \
# 2053                     14+  111023614 2014-12-19 12:00:00+00:00
# 2058               Дуxless 2  111000415 2015-01-26 12:00:00+00:00
# 2472             Воин (2015)  111017315 2015-09-28 12:00:00+00:00
# 2532                 Бармен.  111009615 2015-05-26 12:00:00+00:00
# 2615     Савва. Сердце воина  114001715 2015-07-21 12:00:00+00:00
# 2684          Тряпичный союз  111010215 2015-06-08 12:00:00+00:00
# 2788      Срочно выйду замуж  111017115 2015-09-30 12:00:00+00:00
# 2874       Помню - не помню!  111004916 2016-03-01 12:00:00+00:00
# 3047  Любовь с ограничениями  111008216 2016-04-29 12:00:00+00:00
# 3565       Притяжение (2016)  111018116 2016-12-16 12:00:00+00:00
# 3675                Чудо-юдо  114001817 2017-06-27 12:00:00+00:00
# 3739                    Мифы  111004317 2017-06-07 12:00:00+00:00
# 5673                   Селфи  111012117 2018-02-01 12:00:00+00:00
# ...

# %% [markdown]
# Действительно, в нашей выборке есть фильмы с бюджетом 0. Вероятно, здесь бюджет просто неизвестен.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не проверены возможные аномалии во всех колонках с количественными данными. Не проанализированы их причины.<br>Только не надо их сразу удалять.</font>

# %% [markdown]
# <font color='Blue'><b> Я в прошлой версии добавила боксплоты - это то, что нужно было? Или аномалии анализируются иначе? </b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 4</b></font><br>
# <font color='DarkMagenta'>👉 Визуализация данных — это мощный инструмент для представления информации в наглядной и понятной форме. Различные виды диаграмм и графиков предназначены для разных типов данных и целей анализа. Вот обзор основных типов диаграмм и графиков и их применения:
# - <b>Гистограммы (Hist)</b> : Визуализация распределения числовых данных. Показывают, как часто встречаются различные значения в наборе данных. Полезны для анализа распределений, таких как возраст, доходы, оценки и т.д.
# - <b>Столбчатые диаграммы (Bar Charts)</b> : Сравнение категориальных данных. Показывают количественные значения для различных категорий. Полезны для сравнения продаж по регионам, количества пользователей по возрастным группам и т.д.
# - <b>Круговые диаграммы (Pie Charts)</b> : Визуализация долей целого. Показывают, как части составляют целое. Полезны для представления долей рынка, распределения бюджета и т.д.
# - <b>Линейные графики (Line Charts)</b> : Визуализация изменений во времени. Показывают тренды и изменения данных на протяжении времени. Полезны для анализа временных рядов, таких как курсы акций, температура, продажи и т.д.
# - <b>Точечные диаграммы (рассеяния) (Scatter Plots)</b> : Визуализация взаимосвязей между двумя переменными. Показывают корреляции и зависимости между переменными. Полезны для анализа зависимостей, таких как рост и вес, доходы и расходы и т.д.
# - <b>Диаграммы размаха (Box Plots)</b> : Визуализация распределения данных и выявление выбросов. Показывают медиану, квартили и выбросы в наборе данных. Полезны для анализа распределений и выявления аномалий.
# - <b>Тепловые карты (Heatmaps)</b> : Визуализация плотности данных. Показывают концентрации данных в двухмерном пространстве. Полезны для анализа географических данных, корреляций между переменными и т.д.<br><br>
# Каждый тип диаграммы или графика имеет свои особенности и применяется для различных целей. Выбор подходящего типа визуализации зависит от характера данных и целей анализа.</font>

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
data['year'] = data['show_start_date'].dt.year

# %%
data['year'].describe()
# Out:
# count   7,486.00
# mean    2,014.59
# std         3.01
# min     2,010.00
# 25%     2,012.00
# 50%     2,015.00
# 75%     2,017.00
# max     2,019.00
# Name: year, dtype: float64

# %% [markdown]
# Мы добавили столбец с годом премьеры фильма. Видим, что в нашей выборке представлены фильмы 2010-2019

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['director'].sort_values().unique()
# Out:
# array(['Ёлкин Туйчиев', 'Ён Сан-хо', 'А Андрющенко', ...,
#        'хореография Пьера Лакотта по Филиппу Тальони',
#        'хореография Фредерика Аштона', 'хореография Фредерика Эштона'],
#       dtype=object)

# %%
def new_columns(data, columns):
    for column in columns:
        data[f'new_{column}'] = data[column].dropna().apply(lambda x: x.split(',')[0])
    return data

data = new_columns(data, ['director', 'genres'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   datetime64[ns, UTC]
#  3   type                   7486 non-null   object
#  4   film_studio            7486 non-null   object
#  5   production_country     7486 non-null   object
#  6   director               7486 non-null   object
#  7   producer               7486 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     7486 non-null   float64
#  10  nonrefundable_support  7486 non-null   float64
#  11  budget                 7486 non-null   float64
#  12  financing_source       7486 non-null   object
#  13  ratings                7486 non-null   float64
# ...

# %%
data['new_director']
# Out:
# 0           Кевин Костнер
# 1               Е.Матвеев
# 2       Тимур Бекмамбетов
# 3       Тимур Бекмамбетов
# 4       Тимур Бекмамбетов
#               ...
# 7481          Фил Грабски
# 7482           Ник Пауэлл
# 7483     Чарльз Е.Бастьен
# 7484             А.Беляев
# 7485             И.Трусов
# Name: new_director, Length: 7486, dtype: object

# %%
data['new_genres']
# Out:
# 0           боевик
# 1            драма
# 2       фантастика
# 3       фантастика
# 4       фантастика
#            ...
# 7481    Нет данных
# 7482        боевик
# 7483    Нет данных
# 7484    Нет данных
# 7485       комедия
# Name: new_genres, Length: 7486, dtype: object

# %% [markdown]
# Созданы новые столбцы с жанрами и режиссерами, повторяющие значения первоначальных столбцов до первой запятой в строчке.

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %% [markdown]
# Считаем долю по всей выборке

# %%
(data['refundable_support'].sum() + data['nonrefundable_support'].sum()) / data['budget'].sum()
# Out:
# 0.47823272359243907

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно сделано задание по созданию колонок.</font>

# %% [markdown]
# Гос поддержка в среднем составляет 47,8% от бюджета фильма.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Здесь ожидаются обобщающие выводы по разделу предобработки данных.</font>

# %% [markdown]
# Таким образом, при предобработке данных мы проанализировали наш датасет:
#
# - Отредактированы типы данных (колонка дата премьеры фильма приведена к типу дата, объемы средств гос поддержки, бюджет, рейтинг, сборы - приведены к числовому виду);
#
# - Обработаны пропуски (больше всего данных пропущено по гос поддержке, бюджету и источнику финансирования;
#
# - Обработаны дубликаты (номера прокатных удостоверений приведены к уникальности);
#
# - Изучены категориальные данные датасета (устранены лишние пробелы в начале и в конце строк) и количественные значения;
# - Добавлены новые столбцы -  с именем и фамилией главного режиссёра и основным жанром фильма.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно.</font>

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах. Проанализируйте, как эта доля менялась по годам. Сделайте вывод о том, какой период полнее всего представлен в данных.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что написано в задании: <br><b>Посмотрите, сколько фильмов выходило в прокат каждый год. </b> <br>А это не сделано.</font>

# %% [markdown]
# Рассмотрим общее количество фильмов по годам

# %%
movies_all = data.groupby('year')['title'].count()
movies_all
# Out:
# year
# 2010    985
# 2011    622
# 2012    593
# 2013    630
# 2014    807
# 2015    705
# 2016    818
# 2017    505
# 2018    891
# 2019    930
# Name: title, dtype: int64

# %%
movies_all.plot()
plt.title('Общее количество фильмов по годам')
plt.xlabel('Год')
plt.ylabel('Количество фильмов')
plt.show()

# %% [markdown]
# Теперь посмотрим на динамику количества фильмов с известной информацией о сборах.

# %%
movies_box_office = data.query('box_office > 0').groupby('year')['title'].count()
movies_box_office
# Out:
# year
# 2010    101
# 2011    109
# 2012    123
# 2013    179
# 2014    273
# 2015    462
# 2016    525
# 2017    357
# 2018    475
# 2019    530
# Name: title, dtype: int64

# %%
movies_box_office.plot()
plt.title('Количество фильмов в прокате по годам')
plt.xlabel('Год')
plt.ylabel('Количество фильмов')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно.</font>

# %%
(movies_box_office / movies_all).plot()
plt.title('Доля фильмов с информацией о прокате в кинотеатрах')
plt.xlabel('Год')
plt.ylabel('Доля фильмов от общего количества')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Подписи осей и название нужны для того, чтобы сделать диаграммы и графики понятными и информативными, особенно для заказчика проекта. Без них было бы сложно определить, что именно изображено на графике и какие значения соответствуют каждой оси, так как заказчик не обязан разбираться в коде. Более того, подписи осей помогают установить контекст и понять, какие переменные представлены на графике. По этому при дальнейшем комментировании результатов анализа и визуализации, становятся понятны сделанные из анализа выводы. </font>

# %%
data.query('box_office > 0').groupby('year')['box_office'].count() / data.groupby('year')['puNumber'].count()
# Out:
# year
# 2010   0.10
# 2011   0.18
# 2012   0.21
# 2013   0.28
# 2014   0.34
# 2015   0.66
# 2016   0.64
# 2017   0.71
# 2018   0.53
# 2019   0.57
# dtype: float64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Визуализация данных графиками и диаграммами подразумевает подписи всех осей и название графика  на русском языке, при необходимости наличие меток. Это относится ко всем графикам/диаграммам проекта и является критической ошибкой. Правила оформления проектов описаны "Полезных инструкциях для учёбы".</font>

# %% [markdown]
# Доля фильмов с информацией о сборах составляет по годам от 10,6% до 70,1%. Больше всего доступной информации о фильмах 2017 года. Меньше всего - в 2010, и с каждым годом эта доля имеет тенденцию расти.

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
data.query('box_office >= 0').groupby('year')['box_office'].sum()
# Out:
# year
# 2010        2,428,654.00
# 2011       14,102,765.00
# 2012        6,955,423.00
# 2013       29,799,706.20
# 2014    7,444,951,859.20
# 2015   39,497,365,196.40
# 2016   47,866,299,741.91
# 2017   48,563,707,217.51
# 2018   49,668,403,134.32
# 2019   48,425,708,779.59
# Name: box_office, dtype: float64

# %%
data.query('box_office >= 0').groupby('year')['box_office'].sum().plot()
plt.title('Сумма сборов по годам')
plt.ylabel('Сумма сборов')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошая визуализация и правильно, что оси подписаны и есть название графика.</font>

# %% [markdown]
# Минимальная сумма сборов была в 2010 году (2 428 654 руб.), максимальная - в 2018 году (49 668 403 134 руб.).

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %%
data.query('box_office >= 0').pivot_table(index = 'year', values = 'box_office', aggfunc = ['mean', 'median'])
# Out:
#                mean       median
#          box_office   box_office
# year
# 2010      23,130.04     1,700.00
# 2011     129,383.17     3,000.00
# 2012      54,339.24     5,660.00
# 2013     161,954.92     3,522.50
# 2014  26,684,415.27    18,160.00
# 2015  84,940,570.31 4,920,933.00
# 2016  91,000,569.85 3,846,679.41
# 2017 136,032,793.33 9,968,340.00
# 2018 104,565,059.23 8,891,102.21
# 2019  91,369,261.85 4,627,798.34

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 В разделе предобработки данных на пропуски была поставлена заглушка, при анализе ее необходимо отфильтровывать.<br> Для чего предназначена заглушка? Для сохранения значимых данных в других колонках, отличной той, в которой  заменяем пропуски заглушкой. Но когда анализируем данные колонки с заглушками, то последнюю отфильтровываем, так как эти данные не валидны. Если этого не делаем, то получается, что не совсем правильно понимаем назначение заглушки.<br>А прошлый раз без галушки было правильно:</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %%
data.query('box_office >= 0').pivot_table(index = 'year', values = 'box_office', aggfunc = ['mean', 'median']).plot(style='o-')
plt.title('Изменение среднего и медианы сборов по годам')
plt.ylabel('Сумма сборов')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# Среднее значение с годами сильно перерасло медиану - значит, с 2014 в выборке участились выдающиеся значения с очень большими сборами.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильный вывод. Средняя и медианная сумма сбора существенно отличаются - средняя сумма сборов оказывается в разы выше медианной. Это значит, что среди фильмов есть явные звезды, приносящие своим создателям существенную долю от общего проката. А сборы большей части фильмов весьма скромные.</font>

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Можно сократить строку колонки возрастной категории до значения возраста в кавычках, для этого следует извлечь из строки символы до разделителя `-`.</font>

# %% [markdown]
# <font color='Blue'><b>Попробовала добавить split, но не работает. Что не так?</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Ранее выделяли основной жанр и главного режисёра, подход такой же, только разделитель другой. А тут метод применяется к имени колонки, а не к его содержимому.</font>
# ![image.png](attachment:image.png)

# %%
data.query('box_office > 0').pivot_table(
                index='year',
                columns='age_restriction'.split('-')[0],
                values='box_office',
                aggfunc='sum').plot(style='o-', xlim=[2015, 2019], figsize=(15,10))
plt.title('Изменение суммы сборов по годам по возрастным ограничениям с 2015 по 2019 гг.')
plt.ylabel('Сумма сборов')
plt.xlabel('Год')
plt.show()

# %%
data.query('box_office > 0').pivot_table(
                index='year',
                columns='age_restriction'.split('-')[0],
                values='box_office',
                aggfunc='sum').plot(style='o-', xlim=[2015, 2019], figsize=(15,10))
plt.title('Изменение суммы сборов по годам по возрастным ограничениям с 2015 по 2019 гг.')
plt.ylabel('Сумма сборов')
plt.xlabel('Год')
plt.show()

# %%
def age_short(data, columns):
    for column in columns:
        data[column] = data[column].dropna().apply(lambda x: x.split('-')[0])
    return data

# age_short(data, ['age_restriction'])

# %%
data.query('box_office > 0').pivot_table(
                index='year',
                columns='age_restriction'.split('-')[0],
                values='box_office',
                aggfunc='sum').plot(style='o-', xlim=[2015, 2019], figsize=(15,10))
plt.title('Изменение суммы сборов по годам по возрастным ограничениям с 2015 по 2019 гг.')
plt.ylabel('Сумма сборов')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# Стабильно наименее кассовые фильмы - для любой зрительской аудитории (0+).
# У остальных каегорих показатели сборов гораздо выше. Самые высокие и стадильные сборы - у категории 16+.

# %%
data.query('box_office > 0 & new_genres != "Нет данных" ').groupby('new_genres').agg({'box_office':'sum'}).plot(kind='bar', figsize=(10,5))
plt.title('Динамика суммы сборов фильмов за период по жанрам')
plt.ylabel('Сумма сборов')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Тут и далее в проекте не отфильтрованы заглушки.</font>
# ![image.png](attachment:image.png)

# %%
data.query('box_office > 0 & new_genres != "Нет данных" ').groupby('new_genres').agg({'box_office':'mean'}).plot(kind='bar', figsize=(10,5))
plt.title('Динамика средней суммы сборов фильмов за период по жанрам')
plt.ylabel('Средняя сумма сборов')
plt.xlabel('Жанр')
plt.show()

# %%
data.query('box_office >= 0 & budget >= 0')['box_office'].sum() / data.query('box_office >= 0 & budget >= 0')['budget'].sum()
# Out:
# 1.0376320674283448

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сделаны промежуточные выводы по данному разделу проекта.</font><br>
# <font color='DarkMagenta'>👉 Промежуточный вывод после каждого раздела в проекте помогает понять, какие результаты были получены на данном этапе работы и как они соотносятся с целями и задачами раздела. Он может служить отправной точкой для дальнейшего анализа и развития проекта.<br>
# Кроме того, промежуточный вывод может помочь убедиться, что все необходимые задания были выполнены и результаты соответствуют целям проекта. Это может предотвратить ошибки и проблемы в дальнейшем процессе работы над проектом.<br>
# В целом, написание промежуточного вывода после каждого раздела может быть полезным для понимания прогресса в проекте и обеспечения его качества.<br>
# Промежуточный вывод должен содержать следующие основные моменты:<br>
# - Краткое описание целей и задач раздела.<br>
# - Основные результаты, полученные на данном этапе работы.<br>
# - Анализ полученных результатов и их соответствие целям раздела.<br>
# - Возможные проблемы и трудности, с которыми столкнулись при выполнении раздела.<br>
# - Рекомендации по дальнейшим шагам и развитию проекта.<br>
# Промежуточный вывод должен быть кратким и лаконичным, чтобы не перегружать заказчика лишней информацией.</font>

# %% [markdown]
# Исследовательский анализ данных был проведен в разрезе изучения динамики сборов среди всех фильмов и среди фильмов с известными данные о прокатных сборах.
#
# Общее количество фильмов в нашей выборке менялось неравномерно - наибольшее число фильмов наблюдаются в 2010 и 2019 (более 900 фильмов), а наименьшее - в 2017 и 2012 (меньше 600). Фильмов с известными данными о сборах ещё меньше - с 2010 их число возросло с 101 до 530 в 2019, с восходящим трендом.  Доля фильмов с информацией о прокате в кинотеатрах тоже с годами росла от 10,6% до 70,1%.
#
# Сумма сборов тоже имеет положительную динамику на протяжении всего периода. Минимальная сумма сборов была в 2010 году (2 428 654 руб.), максимальная - в 2018 году (49 668 403 134 руб.).
# Но среднее значение сильно превосходит медиану, значит, большая часть сборов идет от небольшого количества фильмов с очень большими сборами.
#
# Самые большие общие суммы сборов принесли фильмы жанра фантастика и мультфильм, но самые большие средние суммы сторов - у исторических фильмов. Тем не менее, окупаемость фильмов всего датасета - 103,8%.

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Для этого задания следовало создать датасет с отфильтрованными фильмами с господдержкой.</font>

# %% [markdown]
# Выделим фильмы с господдержкой в отдельный датасет.

# %%
data_subset = data.query('refundable_support > 0 | nonrefundable_support > 0')

# %%
data_subset.describe()
# Out:
#        refundable_support  nonrefundable_support           budget  ratings  \
# count              332.00                 332.00           332.00   332.00
# mean        11,864,457.83          48,980,988.89   127,229,716.68     5.68
# std         24,916,555.26          59,980,117.92   188,588,333.12     1.75
# min                  0.00                   0.00             0.00     0.00
# 25%                  0.00          25,000,000.00    42,000,000.00     5.20
# 50%                  0.00          30,000,000.00    68,649,916.00     6.10
# 75%         15,000,000.00          40,375,000.00   141,985,319.50     6.70
# max        180,000,000.00         400,000,000.00 2,305,074,303.00     8.50
#
#             box_office     year
# count           332.00   332.00
# mean    126,847,920.36 2,016.72
# std     328,762,573.59     1.64
# min              -1.00 2,013.00
# 25%         909,431.25 2,015.00
# 50%      12,144,193.50 2,017.00
# 75%     103,107,405.69 2,018.00
# ...

# %% [markdown]
# Отфильтрованный датасет содержит гораздо меньше значений, чем первоначальный - всего 332 наблюдения.

# %%
#data_subset.pivot_table(
#                index='year',
#                columns='new_genres',
#                values='title',
#                aggfunc='count').plot(style='o-', figsize=(15, 10))
#plt.title('Количество вышедших фильмов по жанрам')
#plt.ylabel('Количество фильмов')
#plt.xlabel('Год')
#plt.show()

# %%
# data[data['refundable_support'].notna()].pivot_table(
#                index='year',
#                columns='new_genres',
#                values='title',
#                aggfunc='count').plot(style='o-', figsize=(15, 10))
#plt.title('Количество вышедших фильмов по жанрам')
#plt.ylabel('Количество фильмов')
#plt.xlabel('Год')
#plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что написано в задании: <br><b>Исследуйте фильмы, которые получили государственную поддержку.</b> <br>А анализуруются все, так как пропусков в данных господдержки нет, они заменены нулями.</font>

# %%
#data[data['refundable_support'].notna()].pivot_table(
#                index='year',
#                columns='financing_source',
#                values='box_office',
#                aggfunc='sum').plot(style='o-', figsize=(10, 5))
#plt.title('Изменение объемов возвратных средств')
#plt.ylabel('Сумма возвратных средств')
#plt.xlabel('Год')
#plt.show()

# %%
#data[data['nonrefundable_support'].notna()].pivot_table(
#                index='year',
#                columns='financing_source',
#                values='box_office',
#                aggfunc='sum').plot(style='o-', figsize=(10, 5))
#plt.title('Изменение объемов невозвратных средств')
#plt.ylabel('Сумма возвратных средств')
#plt.xlabel('Год')
#plt.show()

# %%
data_subset.pivot_table(
                index='year',
                columns='financing_source',
                values='box_office',
                aggfunc='sum').plot(style='o-', figsize=(10, 5))
plt.title('Изменение объемов средств господдержки')
plt.ylabel('Сумма средств')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# В нашей выборке информация о фильмах предоставлена только с  2014 года. Данные более ранних лет отсутствуют - или гос поддержки не было, или данные в базе отсутствуют.
#
# Господдержка оказывается преимущественно со стороны Фонда Кино.

# %% [markdown]
# Посмотрим, фильмам каких жанров чаще дают гос поддержку

# %%
data_subset['new_genres'].value_counts().plot(kind='bar', figsize=(10,5))
plt.title('Количество фильмов, получивших господдержку по жанрам')
plt.ylabel('Количество фильмов')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# Среди фильмов с господдержкой больше всего драм и комедий.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен необходимым образом.</font>

# %% [markdown]
# Теперь посмотрим суммированные сборы по жанрам среди фильмов с гос поддержкой.

# %%
data_subset.groupby('new_genres').agg({'box_office':'sum'}).plot(kind='bar', figsize=(10,5))
plt.title('Сумма сборов фильмов с господдержкой по жанрам')
plt.ylabel('Сумма сборов')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен необходимым образом.</font>

# %% [markdown]
# Суммы сборов максимальны среди комедий, драм и мультфильмов. Это соотносится с предыдущим графиком с максимальным количеством фильмов с господдержкой. Получается, что с точки зрения жанров господдержку оказывают фильмам, которые имеют потенциал стать кассовыми.
#
# Сравним средние кассовые сборы фильмов внутри каждого жанра.

# %%
data_subset.groupby('new_genres').agg({'box_office':'mean'}).plot(kind='bar', figsize=(10,5))
plt.title('Средние сборы фильмов с господдержкой по жанрам')
plt.ylabel('Средние сборы')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен необходимым образом.</font>

# %% [markdown]
# Среди фильмов с господдержкой самые высокие средние сборы у представителей жанров спорт и история.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сделан анализ окупаемости фильмов с господдержкой.</font>

# %% [markdown]
# Для расчета окупаемости фильмов с господдержкой найдем отношение суммы сборов к сумме бюджетов.

# %%
data_subset['box_office'].sum() / data_subset['budget'].sum()
# Out:
# 0.996999157666217

# %% [markdown]
# Отношение меньше единицы - получается, что фильмы с господдержкой не окупаются.

# %% [markdown]
# Была проанализирована динамика сборов фильмов с господдержкй по годам и жанрам.
#
# Главным источником господдержки в нашей выборке является Фонд Кино, и предоставляемые средства стабильно увеличивались в период с 2014 по 2019 г.
#
# Больше всего фильмов с господдержкой среди жанров драма и комедия, и суммарно фильмы этого жанра принесли наибольшие сборы за весь период.
# При сравнении средних сборов  лидером оказались немногочисленные фильмы исторического жанра.
#
# Насмотря на возрастающие суммы господдержки и рост доли фильмов с господдержкой среди общего числа, окупаемость этих фильмов не подтвердилась.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Раздел исследования должен заканчиваться расширенным промежуточным выводом по всему разделу.</font>

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# Мы рассмотрели рынок российского проката в разрезе жанров, сборов и наличия гос поддержки. Для этого мы соединили таблицу с фильмами с таблицей со сборами.
#
# В полученном датасете из 7486 наблюдений откорректировали типы данных в колонках с датами премьеры, рейтингом, сборами и бюджетом. обработали пропуски.
#
# Во время обработки пропусков было обнаружено, что в 96% датасета данные о господдержке, бюджете и источнике финансирования отсутствуют.
#
# - Обработаны дубликаты (номера прокатных удостоверений приведены к уникальности);
#
# - Изучены категориальные данные датасета (устранены лишние пробелы в начале и в конце строк) и количественные значения;
# - Добавлены новые столбцы -  с именем и фамилией главного режиссёра и основным жанром фильма.
#
#
# На этапе предобработки данных мы также обнаружили проблему в наименовании типов фильма, стран-производителей и имен режиссеров и создали отдельные столбцы с главным жанром и именем режиссера.

# %% [markdown]
# Несмотря на большую выборку, доступная информация о сборах вырьировалась с 2010 по 2019 гг от 10,6% до 70,1%. Тем не менее, по нашим данным можно установить положительную динамику в отношении сборов и оказания гос поддержки.
# Среди возрастных категорий самые высокие сборы наблюдаются в категории "16+", а среди жанров - спортивные.

# %% [markdown]
# Для рассмотрения фильмов с господдержкой был создан отфильтрованный датасет, который сократился до 332 наблюдений.
#
# Господдержку чаще всего оказывают комедиям и драмам, но самые высоких сборы среди фильмов с господдержкой - у исторических.
#
# Анализ выявил, что фильмы с господдержкой не окупаются - коэффициент окупаемости 99,7%, хотя средняя окупаемость фильмов всего датасета - 571,8%.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Общий вывод проекта должен содержать следующие основные моменты:<br>
# - Краткое описание целей и задач проекта.<br>
# - Основные результаты, полученные в ходе выполнения проекта.<br>
# - Анализ всех разделов проекта, включая раздел анализа и предобработки данных, и их влияния на общие результаты.<br>
# - Возможные направления дальнейшего развития и применения полученных результатов.<br>
# Общий вывод должен быть написан в логической последовательности и отражать общую картину проекта. Он должен быть кратким, но содержательным, чтобы заказчик мог получить полное представление о проекте и его значимости.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вывод должен обобщать весь проект, включая раздел анализа и предобработки данных, суммировать результаты выполнения все заданий и промежуточные выводы разделов всего исследования.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Екатерина, проект отлично структурирован и проработан.<br>Так держать и дальше!<br></font>
# <font color='Red'>🛠 Что нужно, что бы сделать проект лучше:</font><br>
# <font color='Red'>🛠 Сделать проверку и выводы об отсутствии потерь при объединении таблиц. Провести детальный анализ пропусков в датасете. Доделать раздел анализа колонок с категориальными данными, сформулировать общую проблему. Доделать раздел анализа колонок с количественными данными. Сделать выводы по разделу предобработки данных. Сделать анализ выхода фильмов в прокат по годам. Графики и диаграммы необходимо оформить подписями осей и названием графика/диаграммы на русском языке. Написать выводы по разделу исследовательского анализа данных. В шаге 4 исследование проводить в соответствии с заданием только фильмов с господдержкой. Сделать анализ окупаемости фильмов с господдержкой. Написать расширенные выводы по разделу анализа фильмов с господдержкой. Сделать развернутый общий вывод проекта.<br>После исправления ошибок следует проверить и при необходимости откорректировать выводы анализа.</font><br>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов будут приобретены дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Успехов.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Екатерина, увы, остались еще ошибки.<br></font>
# <font color='Red'>🛠 Что нужно доделать:</font><br>
# <font color='Red'>🛠 При анализе необходимо отфильтровывать заглушки.<br>Надо будет проверить выводы,  при необходимости  откорректировать.</font><br>
# <font color='DarkGreen'>👌 Жду исправленный вариант! Успехов.</font>

# %% [markdown]
# <font color='Blue'><b>Спасибо большое за комментарии и замечания!</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 3</b></font><br><br>
# <font color='DarkGreen'>👌 Екатерина! Удалось справиться со всеми заданиями в проекте. Молодец! 😄 Спасибо за работу!<br>
# Входе выполнения проекта научились анализировать первичные данные и проводить обработку датасета. Провели самостоятельный исследовательский анализ. Хочу обратить внимание на качественное оформление графиков и диаграмм, в реальном проекте на их основе затем делается презентация проекта.</font><br>
# <font color='DarkGreen'>👌 Теперь, вперед за новыми знаниями и навыками! Удачи! 😉</font>
# ![image.png](attachment:image.png)

# %%
<font color='Blue'><b>У меня уже сердце упало отСпасибо большое за комментарии и замечания!!</b></font>
# Out:
#   File "/tmp/ipykernel_899/3372598857.py", line 1
#     <font color='Blue'><b>У меня уже сердце упало отСпасибо большое за комментарии и замечания!!</b></font>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 4</b></font><br>
# <font color='DarkGreen'>👌 Привет! Это получается, что я не нату кнопку нажал.</font>
# ![image.png](attachment:image.png)
