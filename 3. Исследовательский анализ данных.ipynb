# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Екатерина, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
#
#
# ---
#
# `PS: из-за этого сообщения может часто возникать ошибка в ноутбуке`. Если мешает, можешь удалить данный комментарий
# </div>

# %% [markdown]
# ### Открываем файл с данными и изучаем общую информацию

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Предлагаю разделять логически разные вещи:
#
#     - импорты библиотек
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# <div class="alert alert-info"> Разделила </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Первичный осмотр данных выявляет несоответствие некоторых наименований столбцов стилю snake_case.

# %%
data = data.rename(columns={'cityCenters_nearest':'city_centers_nearest', 'parks_around3000':'parks_around_3000', 'ponds_around3000':'ponds_around_3000'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Гистограмма для всех числовых столбцов таблицы на одном графике:

# %%
data.hist(figsize=(15, 20), bins=50)
plt.show();

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку `matplotlib.pyplot as plt`
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info"> Добавила </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, так корректнее

# %% [markdown]
# Визуально прослеживается распределение Пуассона у большинства показателей.

# %% [markdown]
# Проверка явных дубликатов

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Наша выборка состоит из 23 699 записей. Наблюдаем наличие пропущенных значений и некорректные типы данных. Явные дубликаты отсутствуют.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на явные дубликаты - основа предобработки данных

# %% [markdown]
# ### Выполняем предобработку данных

# %% [markdown]
# #### Определяем наличие пропусков

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# <div class="alert alert-info"> Спасибо! Пробую: </div>

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_8facd_row0_col0,#T_8facd_row1_col0,#T_8facd_row2_col0,#T_8facd_row3_col0,#T_8facd_row4_col0,#T_8facd_row6_col0,#T_8facd_row8_col0,#T_8facd_row10_col0,#T_8facd_row11_col0,#T_8facd_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8facd_row5_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_8facd_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_8facd_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8facd_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_8facd_row13_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_8facd_row15_col0,#T_8facd_row16_col0,#T_8facd_row17_col0,#T_8facd_row19_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
# ...

# %% [markdown]
# Мы наблюдаем пропуски как в данных, вписанных пользователем, так и заполненных автоматически, на основе картографических данных.

# %% [markdown]
# <div class="alert alert-info"> <b>Вопрос студента (мой):</b> Не до конца понимаю, в какой логике следует рассуждать при заполнении пропущенных значений средним/медианой/нулем/оставлять без изменений/удалять строку. Могу ли попросить комментарий ревьюера по этому вопросу?
#
# Я понимаю, что, например, замена медианой предпочттительнее, чем средним арифметическим, так как медиана менее подвержена влиянию выбросов, но всё равно "не чувствую", когда это безопасно делать.
#
# Далее я выдвинула со своей стороны пару предположений и произвела замену в некоторых данных. </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Не обязательно заполнять все пропуски. Замена пропусков должна быть или рациональной, или оставить их
# </div>

# %% [markdown]
# Рассмотрим столбец о наличии балкона balcony.
# Раз это данные, вписанные пользователем, можно предлоположить, что они пропускались при отсутствии балкона в квартире. Следовательно, заменяем пропуски на ноль.

# %%
data['balcony'].fillna(0, inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# Столбец апартаменты is_apartment.
# В аналогичной логике можно предлоположить, что данные не заполнялись, если квартира не была апартаментами. Следовательно, заменяем пропуски на False.

# %%
data['is_apartment'].fillna(False, inplace=True)

# %% [markdown]
# Пропуски в столбе floors_total. Предполагаю, что человек мог пропустить этот столбец при заполнении, если квартира находится на последнем этаже.

# %%
data['floors_total'].fillna(data['floor'], inplace=True)

# %% [markdown]
# Наблюдаем схожее количество пропусков в столбцах airports_nearest, city_centers_nearest, parks_around_3000,ponds_around_3000 (примерно по 5500), а также в столбцах parks_nearest и ponds_nearest (по 14-15 тысяч).
#
# Рассмотрим срез по одному из параметров.

# %%
data.query('airports_nearest.isna()')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-info"> Визуальный осмотр показывает, что пропуски наблюдаются преимущественно в одних и тех же наблюдениях. Не знаю, как можно дальше развить эту мысль, так как не вижу никаких схожих признаков среди других столбцов для выявления закономерности </div>

# %% [markdown]
# Причины, по котором могли быть пропущены данные, вписанные пользователем, могут включать человеческий фактор - случайный пропуск, незнание данных, намеренный пропуск при заполнени булевых данных (где пропуск равен "нет"). Данные, полученные автоматически, могли быть пропущены по техническому сбою, отсутствию информации в базе.

# %% [markdown]
# #### Изучаем типы данных в выборке

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Наблюдаем в ряде столбцов несоответствие типа с содержанием.
#
#  first_day_exposition - object - должен быть datetime (для того, чтобы можно было работать с датами)
#
#  floors_total - float64 - должен быть int (потому что количеством этажей может быть только целое число)
#
#  balcony - float64 - должен быть int (потому что количеством балконов может быть только целое число)

# %%
data['first_day_exposition'] = pd.to_datetime(
    data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S'
)

# %%
data['floors_total'] = data['floors_total'].astype('int')

# %%
data['balcony'] = data['balcony'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Столбцы имеют корректный тип данных

# %% [markdown]
# #### Анализ значений в столбце locality_name (устранение неявных дубликатов)

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %%
data['locality_name'].nunique()
# Out:
# 364

# %% [markdown]
# Осмотр данных выявляет дублирование ряда наименований

# %%
data['locality_name'] = (
    data['locality_name']
    .str.replace('ё', 'е')
    .replace(['деревня ', 'коттеджный поселок ', 'поселок ', 'городского типа ', 
              'при железнодорожной станции ', 'платформа ', 'садоводческое некоммерческое товарищество ',
             'садовое товарищество ', 'станции ', 'село ', 'пансионат ',
             'городской '], '', regex=True)
)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно например вот так:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
#
# </div>

# %%
data['locality_name'].nunique()
# Out:
# 305

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Агалатово', 'Александровская', 'Алексеевка', 'Аннино', 'Аро',
#        'Барышево', 'Батово', 'Бегуницы', 'Белогорка', 'Белоостров',
#        'Бокситогорск', 'Большая Вруда', 'Большая Ижора',
#        'Большая Пустомержа', 'Большие Колпаны', 'Большое Рейзино',
#        'Большой Сабск', 'Бор', 'Борисова Грива', 'Бугры', 'Будогощь',
#        'Ваганово', 'Важины', 'Вартемяги', 'Вахнова Кара', 'Вещево',
#        'Виллози', 'Вознесенье', 'Возрождение', 'Войсковицы', 'Войскорово',
#        'Володарское', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Вырица', 'Выскатка', 'Высокоключевой', 'Высоцк', 'Гаврилово',
#        'Гарболово', 'Гатчина', 'Гладкое', 'Глажево', 'Глебычево',
#        'Глинка', 'Гончарово', 'Горбунки', 'Гостилицы', 'Громово',
#        'Дзержинского', 'Дружная Горка', 'Дружноселье', 'Дубровка',
#        'Елизаветино', 'Ефимовский', 'Жилгородок', 'Жилпоселок', 'Житково',
#        'Заводской', 'Заклинье', 'Заневка', 'Запорожское', 'Зеленогорск',
# ...

# %% [markdown]
# Таким образом, мы избавились от дубликатов среди названий населенных пунктов.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует вывод после раздела (можно описать качество исходных данных). Поправишь, этот момент в проекте?
# </div>

# %% [markdown]
# <div class="alert alert-info"> Добавляю: </div>

# %% [markdown]
# Таким образом, при предобработке данных были обнаружены и устранены пропуски в столбцах Число балконов, Апартаменты и Количество этажей в доме.
# Наибольшее количество пропусков наблюдается в столбце Апартаменты - 88%.
#
# Откорректирован тип данных в столбцах, где это необходимо:
#  - дата публикации - должна быть датой;
#  - количество этажей в доме - должно быть целых числом;
#  - количество балконов - тоже никак не может быть дробным числом, а только целым.
#
#
# Обработаны наименования населенных пунктов и удалены неявные дубликаты, созданные из-за различных вариантов написания одних и тех же объектов.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Добавляем в таблицу новые столбцы

# %% [markdown]
# #### Цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой)

# %%
data['price_per_square_meter'] = (data['last_price'] / data['total_area']).round(2)

# %%
data['price_per_square_meter']
# Out:
# 0        120370.37
# 1         82920.79
# 2         92785.71
# 3        408176.10
# 4        100000.00
#            ...
# 23694     72490.85
# 23695     52542.37
# 23696     44091.71
# 23697    149511.40
# 23698     41795.67
# Name: price_per_square_meter, Length: 23699, dtype: float64

# %% [markdown]
# #### День недели публикации объявления (0 — понедельник, 1 — вторник и так далее)

# %%
data['exposition_weekday'] = data['first_day_exposition'].dt.weekday

# %%
data['exposition_weekday']
# Out:
# 0        3
# 1        1
# 2        3
# 3        4
# 4        1
#         ..
# 23694    1
# 23695    0
# 23696    6
# 23697    1
# 23698    4
# Name: exposition_weekday, Length: 23699, dtype: int64

# %% [markdown]
# #### Месяц публикации объявления

# %%
data['exposition_month'] = data['first_day_exposition'].dt.month

# %%
data['exposition_month']
# Out:
# 0         3
# 1        12
# 2         8
# 3         7
# 4         6
#          ..
# 23694     3
# 23695     1
# 23696     2
# 23697     3
# 23698     7
# Name: exposition_month, Length: 23699, dtype: int64

# %% [markdown]
# #### Год публикации объявления

# %%
data['exposition_year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#      https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
#
#     и
#
#     https://www.sharpsightlabs.com/blog/pandas-astype/
# </div>

# %%
data['exposition_year']
# Out:
# 0        2019
# 1        2018
# 2        2015
# 3        2015
# 4        2018
#          ...
# 23694    2017
# 23695    2018
# 23696    2018
# 23697    2017
# 23698    2017
# Name: exposition_year, Length: 23699, dtype: int64

# %% [markdown]
# #### Тип этажа квартиры (значения — «первый», «последний», «другой»)

# %%
def categorize_floor(data):
    try:
        if data['floor'] == 1:
            return 'первый'
        elif data['floor'] == data['floors_total']:
            return 'последний'
        return 'другой'
    except:
        pass

# %%
data['floor_category'] = data.apply(categorize_floor, axis=1)

# %%
data['floor_category'].unique()
# Out:
# array(['другой', 'первый', 'последний'], dtype=object)

# %% [markdown]
# #### Расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений)

# %%
data['city_centers_nearest_km'] = (data['city_centers_nearest'] / 1000).round()

# %%
data[['city_centers_nearest', 'city_centers_nearest_km']]
# Out:
#        city_centers_nearest  city_centers_nearest_km
# 0                   16028.0                     16.0
# 1                   18603.0                     19.0
# 2                   13933.0                     14.0
# 3                    6800.0                      7.0
# 4                    8098.0                      8.0
# ...                     ...                      ...
# 23694                4232.0                      4.0
# 23695                   NaN                      NaN
# 23696                   NaN                      NaN
# 23697               10364.0                     10.0
# 23698                   NaN                      NaN
#
# [23699 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ### Проведим исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров (удаление выбросов, построение гистограмм)
#
# Обратимся к описательной статистике

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23699.000000  21796.000000  23699.000000  21421.000000  23699.000000
# mean      10.671463     34.457852      5.892358     10.569807      0.591080
# ...

# %% [markdown]
# Для того, чтобы оценить редкие и выбивающиеся значения, обратимся также к бокс плотам. Для построениея гистограмм удалим выбросы, посчитав границы "усов" (Q1 - 1,5\*IQR ; Q3 + 1.5\*IQR)

# %% [markdown]
# <div class="alert alert-info"> Здесь у меня вопрос, аналогичный теме заполнения пропусков. Есть ли ещё методы определения аномалий, кроме выявления выбросов? </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Определение аномалий можно подходить с разных сторон, помимо просто поиска выбросов
#
# 1. Методы на основе плотности. Пример — алгоритм DBSCAN (Density-Based Spatial Clustering of Applications with Noise), который выделяет аномалии как точки, которые не принадлежат плотным областям данных. Другой вариант — LOF (Local Outlier Factor), который смотрит на локальную плотность точки и сравнивает её с плотностью соседей.
#
# 2. Модели на основе расстояния. Например, K ближайших соседей (KNN). Если расстояние до ближайших соседей для точки сильно больше, чем для других точек, её можно считать аномальной.

# %% [markdown]
# ##### Общая площадь (total_area)

# %%
data.boxplot('total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
69.9+1.5*(69.9-40)
# Out:
# 114.75000000000001

# %% [markdown]
# Со стороны минимального значения выбросов нет, можно взять значение min

# %%
data['total_area'].hist(range=(12,114.8),bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что используешь метод range() для определения пиковых значений
# </div>

# %% [markdown]
# Среди объявлений больше всего квартир общей площадью от 40 до 69.9 кв. метров.
#
# Наблюдаются "пики" около 30, 45, 60, 80 и 100 кв.м. Вероятно, в ряде объявлений общую площадь указывали округленно.
#
# Создадим копию нашего массива данных и уберем из него выбросы.

# %%
good_data = data.query('total_area > 12 & total_area < 114.8')

# %% [markdown]
# ##### Жилая площадь (living_area)

# %%
data.boxplot('living_area')
# Out:
# <AxesSubplot:>

# %%
data['living_area'].describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
42.3+1.5*(42.3-18.6)
# Out:
# 77.85

# %%
data['living_area'].hist(range=(2,77.9), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим всплекс предложений среди квартир с жилой площадью 18, 30 кв.метров. В промежутке между этими значениями - ярко выраженный спад.

# %%
good_data = good_data.query('living_area > 2 & living_area < 77.9')

# %% [markdown]
# #####  Площадь кухни (kitchen_area)

# %%
data.boxplot('kitchen_area')
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
12+1.5*(12-7)
# Out:
# 19.5

# %%
data['kitchen_area'].hist(range=(1.3,19.5), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме всплески среди целых значений. Большинство квартир в выборке с площадями кухни от 7 до 12 кв.м.

# %%
good_data = good_data.query('kitchen_area > 1.3 & kitchen_area < 19.5')

# %% [markdown]
# #####  Цена объекта (last_price)

# %%
data.boxplot('last_price')
# Out:
# <AxesSubplot:>

# %%
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
6800000+1.5*(6800000-3400000)
# Out:
# 11900000.0

# %%
data['last_price'].hist(range=(12190,11900000), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Наиболее встречающаяся цена объектов лежит в диапазоне от 3 400 000 до 680 000 000 р.

# %%
good_data = good_data.query('last_price > 12190 & last_price < 11900000')

# %% [markdown]
# #####  Количество комнат (rooms);

# %%
data.boxplot('rooms')
# Out:
# <AxesSubplot:>

# %%
data['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
3+1.5*(3-1)
# Out:
# 6.0

# %%
data['rooms'].hist(range=(0, 6), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего предложений с 1-3 комнатами.

# %%
good_data = good_data.query('rooms > 0 & rooms < 6')

# %% [markdown]
# #####  Высота потолков (ceiling_height)

# %%
data.loc[data['ceiling_height'] >= 20, 'ceiling_height'] = data['ceiling_height']/10

# %%
data.boxplot('ceiling_height')
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.729608
# std          0.319850
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Считаем левую границу для построения гистограммы (Q1 - 1.5\*IQR)

# %%
2.51-1.5*(2.8-2.51)
# Out:
# 2.0749999999999997

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
2.8+1.5*(2.8-2.51)
# Out:
# 3.235

# %%
data['ceiling_height'].hist(range=(2.07, 3.24), bins=100)
# Out:
# <AxesSubplot:>

# %%
good_data = good_data.query('ceiling_height > 2.07 & ceiling_height < 3.24')

# %% [markdown]
# #####  Тип этажа квартиры («первый», «последний», «другой») (floor_category);

# %%
data['floor_category'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Наблюдаем большую часть наблюдений квартир не на первом и не на последнем этаже. Однако, полагаю, что было бы интересно посмотреть на объем выборки по всем этажам отдельно:

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %%
data.boxplot('floor')
# Out:
# <AxesSubplot:>

# %%
data['floor'].describe()
# Out:
# count    23699.000000
# mean         5.892358
# std          4.885249
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %%
8+1.5*(8-2)
# Out:
# 17.0

# %%
data['floor'].hist(range=(0, 17), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего предложений по квартирам, находящимся на пятом этаже и ниже. Среди квартир, находящихся на более высоких этажах, предложения снижаются.

# %%
good_data = good_data.query('ceiling_height > 0 & ceiling_height <= 17')

# %% [markdown]
# ##### Общее количество этажей в доме (floors_total);

# %%
data.boxplot('floors_total')
# Out:
# <AxesSubplot:>

# %%
data['floors_total'].describe()
# Out:
# count    23699.000000
# mean        10.671463
# std          6.595802
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
16+1.5*(16-5)
# Out:
# 32.5

# %%
data['floors_total'].hist(range=(1,32.5), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего предложений по квартирам в домах до десяти этажей, при увеличении высотности количество предложений снижается.

# %%
good_data = good_data.query('floors_total >= 1 & floors_total <= 32.5')

# %% [markdown]
# ##### Расстояние до центра города в метрах (city_centers_nearest)

# %%
data.boxplot('city_centers_nearest')
# Out:
# <AxesSubplot:>

# %%
data['city_centers_nearest'].describe()
# Out:
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
16293+1.5*(16293-9238)
# Out:
# 26875.5

# %%
data['city_centers_nearest'].hist(range=(181, 26875.5), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим, что больше всего предложений среди квартир, находящихся в районе 5000 и 13000-15000 метрах от центра города.

# %%
good_data = good_data.query('city_centers_nearest >= 181 & city_centers_nearest <= 26875.5')

# %% [markdown]
# ##### Расстояние до ближайшего парка (parks_nearest)

# %%
data.boxplot('parks_nearest')
# Out:
# <AxesSubplot:>

# %%
data['parks_nearest'].describe()
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
612+1.5*(612-288)
# Out:
# 1098.0

# %%
data['parks_nearest'].hist(range=(1, 1098), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Квартиры в нашей выборке находятся на разной удаленности от ближайшего парка. (Среднее расстояние в диапазоне от 288-612 метров)

# %%
good_data = good_data.query('parks_nearest >= 1 & parks_nearest <= 1098')

# %% [markdown]
# #### Изучение скорости продажи квартир (days_exposition)

# %%
data.boxplot('days_exposition')
# Out:
# <AxesSubplot:>

# %%
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Считаем правую границу для построения гистограммы (Q3 + 1.5\*IQR)

# %%
232+1.5*(232-45)
# Out:
# 512.5

# %%
data['days_exposition'].hist(range=(1, 512.5), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим в целом убывание количества объявлений по мере увеличения дней размещения на сайте. Рассмотрим поближе поближе интервал с выраженными пиками/всплесками.

# %%
data['days_exposition'].hist(range=(1, 100), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Наблюдаем всплески на 45, 60, 90 дней. Возможно, в эти дни оканчивается срок размещения объявления, а не происходит сделка по продаже квартиры.

# %% [markdown]
# Считаем среднее и медиану

# %%
data['days_exposition'].mean()
# Out:
# 180.88863436982163

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# Среднее намного больше медианы (так как на среднее оказывают влияние крайние большие значения).
#
# В нашем случай долгими можно считать продажи больше 232 дней, и крайне долгими (выбросами, выдающимися значениями) - более 500 дней.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, свыше 1.5 лет можно назвать быстрой продажей

# %%
good_data = good_data.query('days_exposition >= 1 & days_exposition <= 512.5')

# %%
good_data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 10                5   5050000.0        39.6           2017-11-16      1
# 16               11   6700000.0        82.0           2017-11-23      3
# 18                8   3250000.0        31.0           2017-01-27      1
# 27               20   7100000.0        70.0           2017-05-12      3
# 56               14   4350000.0        41.0           2016-03-28      1
# ...             ...         ...         ...                  ...    ...
# 23671             3   3450000.0        35.3           2017-04-14      1
# 23673             9   3100000.0        23.0           2018-03-19      1
# 23681            13   5250000.0        43.0           2018-05-11      2
# 23686             8   3300000.0        31.0           2017-04-29      1
# 23689            13   3550000.0        35.3           2018-02-28      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# В результате обработки аномалилий удалилось около 90% датасета. Случилось это не из-за аномалий, а из-за того, что когда выполняется срез, то автоматически удаляются строки, которые имеют пропуск в этом столбце. Тут я вижу 2 варианта:
#
# 1. Заменить пропуски, а потом делать срез\
#
# 2. Оставить, как есть
# </div>

# %% [markdown]
# <div class="alert alert-info">  Так мне тогда убрать эту good_data (которая вовсе не good) и всё?
# Просто в следующем разделе у меня не получилось никаких сильных корреляций выявить, поэтому я подумала, что, вероятно, от меня ожидалось выделение среза с "типичными" значениями. Поэтому и создала good_data, в который не включались бы выбросы. Логика должна была быть иная? </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Да, будет корректнее просто удалить good_data. И работать с переменной data
# </div>

# %% [markdown]
# #### Изучение факторов, влияющих на стоимость объектов (last_price)

# %% [markdown]
# ##### Зависимость цены от общей площади (total_area)

# %%
data['last_price'].corr(data['total_area'])
# Out:
# 0.6536750579657242

# %%
data.plot(x='total_area' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость нелинейных данных рассматриваешь через тип графика scatter
# </div>

# %% [markdown]
# ##### Зависимость цены от жилой площади (living_area)

# %%
data['last_price'].corr(data['living_area'])
# Out:
# 0.5664915336952651

# %%
data.plot(x='living_area' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='living_area', ylabel='last_price'>

# %% [markdown]
# ##### Зависимость цены от площади кухни (kitchen_area)

# %%
data['last_price'].corr(data['kitchen_area'])
# Out:
# 0.5198690130216392

# %%
data.plot(x='kitchen_area' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>

# %% [markdown]
# ##### Зависимость цены от количества комнат (rooms)

# %%
data['last_price'].corr(data['rooms'])
# Out:
# 0.3633428499648948

# %%
data.plot(x='rooms' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Зависимости дискретных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (сгруппировав предварительно)
# </div>

# %% [markdown]
# <div class="alert alert-info"> Вот так?
#
# Только я не понимаю, почему график так выглядит... тут же нет наблюдений с количеством комнат больше четырех... </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Не совсем, гистограмма показыват кол-во значений для каждого комнаты (метод count() по сути), а нужно использовать метод plot(). Ниже показал
# </div>

# %%
data.groupby('rooms').agg({'last_price':'mean'}).plot()
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
data.groupby('rooms').agg({'last_price':'mean'}).hist(bins=100)
plt.title('Зависимость цены от количества комнат')
plt.ylabel('last_price')
plt.xlabel('rooms')
plt.show()

# %% [markdown]
# ##### Зависимость цены от этажа, на котором расположена квартира (первый, последний, другой) (floor_category)

# %%
data.plot(x='floor_category' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='floor_category', ylabel='last_price'>

# %% [markdown]
# Судя по графику,цены на квартиры, расположенные на первом этаже, ниже.

# %% [markdown]
# ##### Зависимость цены от даты размещения (день недели, месяц, год)

# %%
data.plot(x='first_day_exposition' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='first_day_exposition', ylabel='last_price'>

# %%
data.plot(x='exposition_weekday' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='exposition_weekday', ylabel='last_price'>

# %%
data.plot(x='exposition_month' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='exposition_month', ylabel='last_price'>

# %%
data.plot(x='exposition_year' , y='last_price', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='exposition_year', ylabel='last_price'>

# %% [markdown]
# Сильная корреляция между ценой и прочими факторами не выявлена (кэффициент Пирсона везде меньше 0,7).
#
# Рассмотрим наши данные без учета выбросов.

# %%
good_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2466 entries, 10 to 23689
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             2466 non-null   int64
#  1   last_price               2466 non-null   float64
#  2   total_area               2466 non-null   float64
#  3   first_day_exposition     2466 non-null   datetime64[ns]
#  4   rooms                    2466 non-null   int64
#  5   ceiling_height           2466 non-null   float64
#  6   floors_total             2466 non-null   int64
#  7   living_area              2466 non-null   float64
#  8   floor                    2466 non-null   int64
#  9   is_apartment             2466 non-null   bool
#  10  studio                   2466 non-null   bool
#  11  open_plan                2466 non-null   bool
#  12  kitchen_area             2466 non-null   float64
#  13  balcony                  2466 non-null   int64
# ...

# %%
good_data.isna().sum()
# Out:
# total_images                  0
# last_price                    0
# total_area                    0
# first_day_exposition          0
# rooms                         0
# ceiling_height                0
# floors_total                  0
# living_area                   0
# floor                         0
# is_apartment                  0
# studio                        0
# open_plan                     0
# kitchen_area                  0
# balcony                       0
# locality_name                 2
# airports_nearest              6
# city_centers_nearest          0
# parks_around_3000             0
# parks_nearest                 0
# ponds_around_3000             0
# ponds_nearest              1183
# days_exposition               0
# price_per_square_meter        0
# exposition_weekday            0
# exposition_month              0
# exposition_year               0
# floor_category                0
# city_centers_nearest_km       0
# dtype: int64

# %% [markdown]
# Посмотрим, выявится ли сильная корреляционная связь в таком варианте.

# %%
good_data[['last_price',
           'total_area', 
           'living_area',
           'kitchen_area',
           'rooms',
           'price_per_square_meter',
           'floor_category',
           'exposition_weekday',
           'exposition_month',
           'exposition_year']].corr()
# Out:
#                         last_price  total_area  living_area  kitchen_area  \
# last_price                1.000000    0.785971     0.649789      0.549554
# total_area                0.785971    1.000000     0.915627      0.433358
# living_area               0.649789    0.915627     1.000000      0.156148
# kitchen_area              0.549554    0.433358     0.156148      1.000000
# rooms                     0.495660    0.799136     0.891347      0.000343
# price_per_square_meter    0.441196   -0.178095    -0.275072      0.259900
# exposition_weekday        0.001725   -0.029234    -0.019311     -0.016297
# exposition_month          0.020776    0.040635     0.033925      0.027969
# exposition_year          -0.017270   -0.106428    -0.090890     -0.071466
#
#                            rooms  price_per_square_meter  exposition_weekday  \
# last_price              0.495660                0.441196            0.001725
# ...

# %%
pd.plotting.scatter_matrix(good_data[['last_price',
           'total_area', 
           'living_area',
           'kitchen_area',
           'rooms',
           'price_per_square_meter',
           'floor_category',
           'exposition_weekday',
           'exposition_month',
           'exposition_year']])
plt.show();

# %% [markdown]
# Наиболее сильная из выявленный связей - положительная связь между ценой объекта и общей площадью (коэф корреляции 0,79). Чем больше квартира, тем она дороже. Логично.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Корреляцию есть смысл рассчитывать только для нелинейных данных (в нашем случае это площади)
# </div>

# %% [markdown]
# #### Средние цены кв. метра по населенным пунктам

# %%
local_price = data.pivot_table(index='locality_name', values='price_per_square_meter', aggfunc=['count', 'mean'])

# %%
local_price.columns = ('count', 'mean')

# %%
top_10 = local_price.sort_values('count', ascending=False).head(10)

# %%
top_10
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15721  114849.008793
# Мурино             590   86087.512017
# Кудрово            472   95324.930508
# Шушары             440   78677.364318
# Всеволожск         398   68654.473970
# Пушкин             369  103125.819377
# Колпино            338   75424.579112
# Парголово          327   90175.913089
# Гатчина            307   68746.146515
# Выборг             237   58141.909325

# %% [markdown]
# Перед нами топ-10 городов по количеству объявлений.
#
# Теперь определим среди них представителей с максимальной и минимальной стоимостью квадратного метра.

# %%
top_10.sort_values(by='mean').tail(1)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15721  114849.008793

# %%
top_10.sort_values(by='mean').head(1)
# Out:
#                count          mean
# locality_name
# Выборг           237  58141.909325

# %% [markdown]
# Самый дорогой квадратный метр - в Санкт-Петербурге, 114 849 р.
# Самая низкая стоимость - в Выборге, 58 142 р. за кв.метр.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Правильно

# %% [markdown]
# #### Средняя цена в СПб

# %%
spb_data = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='city_centers_nearest_km', values='last_price', aggfunc=['count', 'mean'])

# %%
spb_data.columns = ('count', 'mean')

# %%
spb_data
# Out:
#                          count          mean
# city_centers_nearest_km
# 0.0                         27  3.144912e+07
# 1.0                        192  2.120672e+07
# 2.0                        310  1.778832e+07
# 3.0                        350  1.112658e+07
# 4.0                        688  1.330428e+07
# 5.0                        920  1.449912e+07
# 6.0                        618  1.533842e+07
# 7.0                        420  1.477515e+07
# 8.0                        597  9.957717e+06
# 9.0                        593  6.950659e+06
# 10.0                       719  6.504119e+06
# 11.0                      1178  6.250815e+06
# 12.0                      1605  5.828545e+06
# 13.0                      1457  6.083141e+06
# 14.0                      1279  5.629101e+06
# 15.0                      1568  5.884751e+06
# 16.0                      1265  5.373131e+06
# 17.0                       883  5.292395e+06
# 18.0                       261  5.091331e+06
# ...

# %%
spb_data['mean'].plot(style='o-')
plt.title('Средняя стоимость квартииры в г. СПб в зависимости от расстояния до центра')
plt.ylabel('Средняя стоимость квартиры')
plt.xlabel('Расстояние до центра, км')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Рекомендую оформлять визуализацию подписями осей абсцисс/ординат и заголовки.
#
#     plt.title('Название заголовка')
#     plt.ylabel('Название оси ординат')
#     plt.xlabel('Название оси абсцисс')
#     plt.show()

# %% [markdown]
# Перед нами график изменения цены по мере удаления предлагаемых к продаже квартир от центра города. Визуально прослеживается обратная зависимость.

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# Был проведен анализ объявлений о продаже квартир на сервисе Яндекс Недвижимость.
# Данные были загружены с учетом разделителя \t, изучена общая информация.
#
# При предобработке данных был унифицирован стиль наименований стобцов (чтобы все были snake_case), заполнены некоторые из пропущенных значений, откорректированы типы данных и неявные дубликаты в столбце с населенными пунктами.
#
# Добавлены новые стобцы с информацией о цене одного кв. метра, дне недели/ месяце/годе публикации, типе этажа квартиры и расстояния до центра в км и изучены параметры. В частности, обычно продолжительность продажи в среднем занимает 95-180 дней. Долгими можно считать продажи больше 232 дней, и крайне долгими (выбросами, выдающимися значениями) - более 500 дней а крайне Быстрые продажи - меньше 45 дней.
#
# При изучении корреляционной связи на всей выборке не проследилось сильной зависимости стоимости объекта от рассмотренных факторов. При удалении выбросов сильная связь (0,79) выявилась только между ценой объекта и общей площадью.
#
# Среди населенных пунктов с наибольшим количеством объявлений самый дорогой кв. метр - в Санкт-Петербурге (114 849 р.), и наименее дорогой - в Выборге (58 142 р.).
#
# При изучении стоимости квартир в Санкт-Петербурге и ее изменении по мере удаления от центра выявлена обратная зависимость - чем дальше от центра, тем дешевле объект.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Срез данных
#
# 2) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 3) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
